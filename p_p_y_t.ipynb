# %%
import random

# %%
# 1. Definimos los puntos para ganar
puntos_para_ganar = 3

# %%
import random 
try:
   def obtener_eleccion_jugador():
     while True:
        eleccion = input("Elige Piedra, Papel o Tijera: ").lower()
        if eleccion in ["piedra", "papel", "tijera"]:
            return eleccion
except:
   print("Opción no válida. Por favor, escribe piedra, papel o tijera: ")



def jugar_contra_ordenador():
    puntos_jugador = 0
    puntos_ordenador = 0
    puntos_para_ganar = 3
    ordenador = random.choice(["piedra", "papel", "tijera"])

   

    # 2. Función para obtener la elección del jugador

    while puntos_jugador < puntos_para_ganar and puntos_ordenador < puntos_para_ganar: 
        print(f"\nMarcador → 👤: {puntos_jugador} |  💻 : {puntos_ordenador}")

        jugador = obtener_eleccion_jugador()
        ordenador = random.choice(["piedra", "papel", "tijera"])

        if jugador == ordenador:
            print("¡Es un empate!🤝 ")
        elif (jugador == "🪨" and ordenador == "✂️") or \
             (jugador == "✂️" and ordenador == "📄") or \
             (jugador == "📄" and ordenador == "🪨"):
            print("¡Ganaste esta ronda!")
            puntos_jugador += 1
        else:
            print("La computadora gana esta ronda.")
            puntos_ordenador += 1

        print(f"Marcador: 👤 {puntos_jugador} - 💻 {puntos_ordenador}\n")

    if puntos_jugador == puntos_para_ganar:
            
            print("¡FELICIDADES! Has ganado el juego. 🏆")
    else:
        print("Lo siento, el ordenador ha ganado el juego. ¡Sigue practicando!☹️")

# %%
jugar_contra_ordenador()
# Out:
# Marcador → 👤: 0 |  💻 : 0
# La computadora gana esta ronda.
# Marcador: 👤 0 - 💻 1
#
#
# Marcador → 👤: 0 |  💻 : 1
# ¡Es un empate!
# Marcador: 👤 0 - 💻 1
#
#
# Marcador → 👤: 0 |  💻 : 1
# ¡Es un empate!
# Marcador: 👤 0 - 💻 1
#
#
# Marcador → 👤: 0 |  💻 : 1
# La computadora gana esta ronda.
# Marcador: 👤 0 - 💻 2
#
#
# Marcador → 👤: 0 |  💻 : 2
# La computadora gana esta ronda.
# Marcador: 👤 0 - 💻 3
#
# Lo siento, el ordenador ha ganado el juego. ¡Sigue practicando!☹️

# %%
def juego_multijugador(): 
 puntos_jugador1  = 0
 puntos_jugador2  = 0
 puntos_para_ganar = 3
 #uso una tupla que no puede ser modificada
 lista_de_opciones = ("piedra","papel","tijera")

 while puntos_jugador1 < puntos_para_ganar and puntos_jugador2 < puntos_para_ganar:
#eleciones de los jugadores
   jugador1 = input("ELIGE PIEDRA,PAPEL,TIJERA").lower()
   jugador2 = input("ELIGE PIEDRA,PAPEL,TIJERA").lower()
   #imprimimos para recordar las elecciones de cada jugador 
   print(f"🔵 ha elegido:--> {jugador1}  | 🔴  ha elegido:--> {jugador2}")
   #para que solo me de como validas las tres opciones,si no te valida cuanquier palabra  
   if jugador1 not in lista_de_opciones or jugador2 not in lista_de_opciones:
        print(" ⚠️ Opción no válida. Por favor, escribe piedra, papel o tijera")
   elif jugador1 == jugador2:
        print("¡Es un empate! 🤝 ")
        continue #salta al inicio del bucle sin sumar puntos
   elif jugador1 == "🪨" and jugador2 == "✂️":
        #suma de cada vuelta 1
        puntos_jugador1 =  puntos_jugador1 + 1
        print(f"Marcador: 🔵 {puntos_jugador1}   | 🔴 {puntos_jugador2}" )
   elif jugador1 == "📄" and jugador2 == "🪨":
        #suma de cada vuelta 1
        puntos_jugador1 = puntos_jugador1 + 1
        print(f"Marcador: 🔵 {puntos_jugador1}   | 🔴 {puntos_jugador2}")
   elif jugador1 == "✂️" and jugador2 == "📄":
        #suma de cada vuelta 1
        puntos_jugador1 = puntos_jugador1 + 1
        print(f"Marcador: 🔵 {puntos_jugador1}   | 🔴 {puntos_jugador2}")     
   #si ninguna de las anteriores se cumple entonces ganaria jugador2
   else:
        puntos_jugador2 = puntos_jugador2 + 1
        print(f"Marcador: 🔵 {puntos_jugador1}   | 🔴 {puntos_jugador2}") 
 #salimos del while para ver quien consigio 3 puntos       
 if puntos_jugador1 == 3:
     return "🔵 , ¡FELICIDADES! Has ganado el juego. 🏆"
 else:
     return "🔴 , ¡FELICIDADES! Has ganado el juego. 🏆"

# %%
juego_multijugador()
# Out:
# 🔵 ha elegido:--> piedra  | 🔴  ha elegido:--> papel
# Marcador: 🔵 0   | 🔴 1
# 🔵 ha elegido:--> papel  | 🔴  ha elegido:--> tijera
# Marcador: 🔵 0   | 🔴 2
# 🔵 ha elegido:--> piedra  | 🔴  ha elegido:--> tijera
# Marcador: 🔵 0   | 🔴 3
# '🔴 , ¡FELICIDADES! Has ganado el juego. 🏆'

# %%
jugar_contra_ordenador()
# Out:
# Marcador → 👤: 0 |  💻 : 0
# La computadora gana esta ronda.
# Marcador: 👤 0 - 💻 1
#
#
# Marcador → 👤: 0 |  💻 : 1
# La computadora gana esta ronda.
# Marcador: 👤 0 - 💻 2
#
#
# Marcador → 👤: 0 |  💻 : 2
# La computadora gana esta ronda.
# Marcador: 👤 0 - 💻 3
#
# Lo siento, el ordenador ha ganado el juego. ¡Sigue practicando!☹️

# %%
puntos_para_ganar = 3

def bienvenida():

   print("¡Bienvenido al juego de 🪨 ,📄  o ✂️!")
   print(f"El primero en llegar a {puntos_para_ganar} puntos gana.\n")


   juego_multijugador()
   jugar_contra_ordenador()
   bienvenida()
while True: 
   eleccion_juego = input("Elige como quieres jugar : MULTIJUGADOR  o ORDENADOR ").lower().strip()
   if eleccion_juego == "multijugador":
      juego_multijugador() #llama a la funcion que ya existe
   elif eleccion_juego == "ordenador":
      jugar_contra_ordenador() 
   elif eleccion_juego == "salir":
      break
         
   else:
       print("Opción no válida vuelve a intentarlo. Vuelve a intentarlo")
# Out:
# Marcador → 👤: 0 |  💻 : 0
